# %%
# %load_ext autoreload
# %autoreload 2

# %%
from deeporigin.drug_discovery import  BRD_DATA_DIR, Protein, Ligand, LigandSet, SystemPrep, PreparedSystem
from deeporigin.platform import DeepOriginClient

client = DeepOriginClient()

# %%
ligands = LigandSet.from_dir(BRD_DATA_DIR)
protein = Protein.from_file(BRD_DATA_DIR / "brd.pdb")

# %%
sp = SystemPrep(ligand=ligands[0], protein=protein)

# %%
system = sp.run()

# %%
system.show()

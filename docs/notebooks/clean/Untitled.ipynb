# %%
from deeporigin.platform import DeepOriginClient
from deeporigin.drug_discovery import Protein, Ligand

client = DeepOriginClient(org_key="gabriel-dev")
client

# %%
client.executions.get_execution(execution_id="fd9e820c-f614-4992-9669-c5d87d160023")

# %%
client.files.download_many("tool-runs/fd9e820c-f614-4992-9669-c5d87d160023/")

# %%
protein = Protein.from_file(client.files.download("/seeded/proteins/1EBY/1EBY_prepared.pdb"))
protein.show(ligand=ligand)

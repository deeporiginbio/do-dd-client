# %%
from deeporigin.drug_discovery import Protein, Ligand

# %%
protein = Protein.from_pdb_id("1NSG")
ligand = protein.extract_ligand()

# %%
ligand

# %%
ligand = Ligand.from_sdf("/Users/srinivas/Downloads/9fa.sdf")
ligand.show()

# %%
Protein.from_file("/Users/srinivas/Downloads/1NSG-sf.cif")

# %%
ligand.smiles

# %%
protein = Protein.from_file("/Users/srinivas/Downloads/1nsg-assembly1.cif")
ligand = protein.extract_ligand()

# %%
protein = Protein.from_file("/Users/srinivas/Downloads/arrb2-homol-lig-docked.pdb")
protein.show()

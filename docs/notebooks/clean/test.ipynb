# %%
from deeporigin.drug_discovery import (
    BRD_DATA_DIR,
    Docking,
    Ligand,
    Pocket,
    PocketFinder,
ABFE,
    Protein,
ABFEParams
)

# %%
from deeporigin.platform import DeepOriginClient

client = DeepOriginClient()

# %%
client.files.download_many(files=client.files.list("tool-runs/eb2d0ace-8637-485b-be50-3d9159cbfd2a"))

# %%
protein = Protein.from_pdb_id("1AB1")
protein.show()

# %%
pf = PocketFinder(protein, pocket_count=1)
pockets = pf.run()

# %%
protein.local_path

# %%
ligand = Ligand.from_sdf(BRD_DATA_DIR / "brd-2.sdf")

# %%
docking = Docking(protein=protein, pocket=pocket, ligand=ligand)
docking.start(quote=True)
docking.estimate

# %%
poses = docking.run()

# %%
poses.download()
protein.show(poses=poses)

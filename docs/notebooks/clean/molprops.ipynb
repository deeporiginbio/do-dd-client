# %%
# %load_ext autoreload
# %autoreload 2

# %%
from deeporigin.drug_discovery import Molprops, BRD_DATA_DIR, LigandSet, Ligand

# %%
ligands = LigandSet.from_sdf("/Users/srinivas/Desktop/ligands/BRAF_actives_dl.sdf")
ligands = ligands[:100]

# %%
mp = Molprops(ligands=ligands, props=['ames','logp'])

# %%
mp.properties

# %%
mp.run()

# %%
ligands

# %%
mp = Molprops(ligands=ligands)

# %%
mp.quote()

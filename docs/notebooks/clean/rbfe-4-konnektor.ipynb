# %%
from dotenv import load_dotenv
load_dotenv()

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # RBFE (just using Konnektor)
#
# In this notebook we show how to use Konnektor as a stand-alone tool

# %% [markdown]
# ## Setup

# %%
from deeporigin.drug_discovery import (
    BRD_DATA_DIR,
    Ligand,
    Protein,
    RBFEParams,
    Konnektor,
)
from deeporigin.platform import DeepOriginClient

client = DeepOriginClient()
client

# %% [markdown]
# ## 1. Load structures and register on the data platform
#
# We use the BRD4 example protein and two congeneric ligands from the bundled
# dataset. `sync()` uploads files (when needed) and registers records on the
# data platform.

# %%
protein = Protein.from_file(BRD_DATA_DIR / "brd.pdb")
protein.sync()
protein.id

# %%
ligands = []
for ligand_file in ["brd-2.sdf", "brd-3.sdf", "brd-4.sdf"]:
    ligand = Ligand.from_sdf(BRD_DATA_DIR / ligand_file)
    ligand.sync()
    ligands.append(ligand)
    

ligands

# %% [markdown]
# ## Generate a network using Konnektor

# %%
kn = Konnektor(ligands=ligands)
ligand_pairs = kn.run()
